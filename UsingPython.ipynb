# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
Scola_College = pd.read_excel('/content/drive/My Drive/Project: bamboozle/2019 대학 데이터셋/학교_재학생_교외_교내.xlsx')
Scola_College.head()
# Out:
#             대학교명    학생수           교외           교내
# 0      가야대학교(김해)   2520   6085217107   3174124932
# 1          가천대학교  17874  31783520857  29677679226
# 2       가톨릭관동대학교   8028  17139043012   8660668208
# 3         가톨릭대학교   6850  13402774236   8259730425
# 4  가톨릭대학교 _제2캠퍼스    672   1048347920    826323470

# %%
print(Scola_College.columns)
# Out:
# Index(['대학교명', '학생수', '교외', '교내'], dtype='object')

# %%
College = Scola_College.loc[:, '대학교명']

# %%
College.head()
# Out:
# 0        가야대학교(김해)
# 1            가천대학교
# 2         가톨릭관동대학교
# 3           가톨릭대학교
# 4    가톨릭대학교 _제2캠퍼스
# Name: 대학교명, dtype: object

# %%
Student = Scola_College.loc[:, '학생수']

# %%
Student.head()
# Out:
# 0     2520
# 1    17874
# 2     8028
# 3     6850
# 4      672
# Name: 학생수, dtype: int64

# %%
Extern = Scola_College.loc[:, '교외']
Intern = Scola_College.loc[:, '교내']

# %%
Extern.head()
# Out:
# 0     6085217107
# 1    31783520857
# 2    17139043012
# 3    13402774236
# 4     1048347920
# Name: 교외, dtype: int64

# %%
Intern.head()
# Out:
# 0     3174124932
# 1    29677679226
# 2     8660668208
# 3     8259730425
# 4      826323470
# Name: 교내, dtype: int64

# %%
Scola_College['교외/재학생'] = Scola_College['교외'] / Scola_College['학생수']

# %%
Scola_College['교내/재학생'] = Scola_College['교내'] / Scola_College['학생수']
Scola_College.head()
# Out:
#             대학교명    학생수           교외           교내        교외/재학생        교내/재학생
# 0      가야대학교(김해)   2520   6085217107   3174124932  2.414769e+06  1.259573e+06
# 1          가천대학교  17874  31783520857  29677679226  1.778199e+06  1.660383e+06
# 2       가톨릭관동대학교   8028  17139043012   8660668208  2.134908e+06  1.078808e+06
# 3         가톨릭대학교   6850  13402774236   8259730425  1.956609e+06  1.205800e+06
# 4  가톨릭대학교 _제2캠퍼스    672   1048347920    826323470  1.560042e+06  1.229648e+06

# %%
Extern_College = Scola_College.loc[:, ['대학교명', '교외/재학생']]

# %%
Extern_College.head()
Extern_College_sort = Extern_College.sort_values(by='교외/재학생', ascending=1)
Extern_College_sort = Extern_College_sort.reset_index(drop=True)

# %%
Extern_College.plot(kind='bar')

# %%
Intern_College = Scola_College.loc[:, ['대학교명', '교내/재학생']]
Intern_College = Intern_College.sort_values(by='교내/재학생', ascending=1)

# %%
Intern_College.plot(kind='bar')

# %%
# !apt -qq -y install fonts-nanum
# Out:
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 21 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 144611 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()

# %%
Intern_College_1 = Intern_College.loc[:30]
